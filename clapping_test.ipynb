# %%
from audio import *

# %%
fs = 44100
T = 2

#record_audio('sound_files/claps/clap_stairs.wav', T, fs)
#play_audio('sound_files/clap_bedroom')

plot_audio('sound_files/claps/clap_living_room.wav')
